# %%
import pandas as pd
df_ex=pd.read_parquet('../data/raw_data.parquet')
df_ex.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 536321 entries, 0 to 536320
# Data columns (total 9 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   id_transaccion  536321 non-null  str
#  1   id_vehiculo     536321 non-null  int64
#  2   id_ubicacion    536321 non-null  int64
#  3   id_cliente      536321 non-null  int64
#  4   fecha           536321 non-null  str
#  5   unidades        536321 non-null  int64
#  6   venta_bruta_sn  536321 non-null  float64
#  7   modelo          536321 non-null  str
#  8   marcas_cl       536321 non-null  str
# dtypes: float64(1), int64(4), str(4)
# memory usage: 52.6 MB

# %%
df_ex['fecha']=pd.to_datetime(df_ex['fecha'])
df_ex['fecha']
# Out:
# 0        2024-12-01
# 1        2022-09-22
# 2        2024-12-01
# 3        2024-04-27
# 4        2025-11-13
#             ...
# 536316   2022-11-02
# 536317   2023-06-13
# 536318   2024-11-13
# 536319   2022-02-02
# 536320   2023-06-26
# Name: fecha, Length: 536321, dtype: datetime64[us]

# %%
df_ex.head(15)
# Out:
#    id_transaccion  id_vehiculo  id_ubicacion  id_cliente      fecha  unidades  \
# 0      ST-2000000            1             1        2536 2024-12-01         1
# 1      ST-2000001            2             2        4867 2022-09-22         1
# 2      ST-2000002            3             1        4669 2024-12-01         1
# 3      ST-2000003            4             3         899 2024-04-27         1
# 4      ST-2000004            5             4        2471 2025-11-13         1
# 5      ST-2000005            6             4        6717 2022-01-06         1
# 6      ST-2000006            7             1        3359 2024-05-07         1
# 7      ST-2000007            1             4        3313 2024-06-07         1
# 8      ST-2000008            8             1        2377 2023-06-16         1
# 9      ST-2000009            4             2        1750 2022-05-16         1
# 10     ST-2000010            4             4       15052 2022-03-03         1
# ...

# %%
df_ex.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 536321 entries, 0 to 536320
# Data columns (total 9 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   id_transaccion  536321 non-null  str
#  1   id_vehiculo     536321 non-null  int64
#  2   id_ubicacion    536321 non-null  int64
#  3   id_cliente      536321 non-null  int64
#  4   fecha           536321 non-null  datetime64[us]
#  5   unidades        536321 non-null  int64
#  6   venta_bruta_sn  536321 non-null  float64
#  7   modelo          536321 non-null  str
#  8   marcas_cl       536321 non-null  str
# dtypes: datetime64[us](1), float64(1), int64(4), str(3)
# memory usage: 47.5 MB
