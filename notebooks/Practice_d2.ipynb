# %%
import pandas as pd
import numpy as np

df=pd.read_parquet('../data/cl_data.parquet')
df.head(10)
# Out:
#   id_transaccion  id_vehiculo  id_ubicacion  id_cliente      fecha  unidades  \
# 0     ST-2000000            1             1        2536 2024-12-01         1
# 1     ST-2000001            2             2        4867 2022-09-22         1
# 2     ST-2000002            3             1        4669 2024-12-01         1
# 3     ST-2000003            4             3         899 2024-04-27         1
# 4     ST-2000004            5             4        2471 2025-11-13         1
# 5     ST-2000005            6             4        6717 2022-01-06         1
# 6     ST-2000006            7             1        3359 2024-05-07         1
# 7     ST-2000007            1             4        3313 2024-06-07         1
# 8     ST-2000008            8             1        2377 2023-06-16         1
# 9     ST-2000009            4             2        1750 2022-05-16         1
#
#    venta_bruta       marca    modelo  anio        mes       dia
# ...
